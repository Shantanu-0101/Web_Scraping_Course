# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()
driver.maximize_window()

url = "https://www.google.com/search?sca_esv=4aee882adbe694f9&sxsrf=AE3TifPp8JKfU9taE44NSrL1qtc-N4jv4A:1764585406781&udm=2&fbs=AIIjpHxU7SXXniUZfeShr2fp4giZrjP_Cx0LI1Ytb_FGcOviEiTm5uW1q0uNfK7KsnoL8hWZUZ3ZEPhe0cPqXxrOlmBaXNrzSbxDmRd08BPr8JCE3oSKIlfO1lQ1Q1cPOiqqF26H7BwlT71tVrjyvuowtIvtChS_MhHUI6sNWOvTkvi8ZCXU0BJa06Ier6L-X6qyrHr2yLdxmM2vjQtP7SmeyYrRY99JCw&q=arsenal&sa=X&ved=2ahUKEwi4juPymJyRAxVgTWcHHVlFHwwQtKgLegQIEhAB&biw=1280&bih=585&dpr=1.5"
driver.get(url)
time.sleep(3)

prev_height = driver.execute_script('return document.body.scrollHeight')
while True:
    print(f"webpage height: {prev_height} pixels")
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    time.sleep(10)

    new_height = driver.execute_script('return document.body.scrollHeight')

    if prev_height == new_height:
        print("Reached page's end no more data")
        break

    prev_height=new_height
# Out:
# webpage height: 6005 pixels
# webpage height: 11709 pixels
# webpage height: 17661 pixels
# webpage height: 23718 pixels
# Reached page's end no more data
