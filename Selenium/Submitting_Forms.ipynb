# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### Practicing with GitHub

# %%
driver = webdriver.Chrome()
driver.maximize_window()

url = "https://github.com/login"
driver.get(url)
time.sleep(2)

#Username field
username_field = driver.find_element(By.ID, "login_field")
username_field.send_keys("Shantanu")
time.sleep(2)

#password field
pass_field = driver.find_element(By.ID, "password")
pass_field.send_keys("Pass@1234")
time.sleep(2)

# submit field
submit_button = driver.find_element(By.XPATH, '/html/body/div[1]/div[3]/main/div/div[2]/form/div[3]/input')
submit_button.click()
time.sleep(2)


driver.quit()

# %% [markdown]
# ### Practicing with Instagram log in page

# %%
driver = webdriver.Chrome()
driver.maximize_window()

url = "https://www.instagram.com/?flo=true"
driver.get(url)

#Username field
username = driver.find_element(By.XPATH, '//*[@id="loginForm"]/div[1]/div[1]/div/label/input')
username.send_keys("Shantanu.edits")
time.sleep(2)

#Password field
pass_field = driver.find_element(By.XPATH, '//*[@id="loginForm"]/div[1]/div[2]/div/label/input')
pass_field.send_keys("Shant@123")
time.sleep(2)

#login button
login = driver.find_element(By.XPATH, '//*[@id="loginForm"]/div[1]/div[3]')
login.click()
time.sleep(10)

# #reels button
# reels_button = driver.find_element(By.XPATH, "//span[contains(text(),'Reels')]")
# reels_button.click()
# time.sleep(5)

# #scroll down
# scroll_button = driver.find_element(By.XPATH, '//*[@id="mount_0_0_Pp"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[2]')
# scroll_button.click()
# time.sleep(2)

# logout_button = driver.find_element(By.XPATH, '/html/body/div[6]/div[1]/div/div[2]/div/div/div/div/div/button[9]')
# logout_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[7], line 28
#      25 time.sleep(5)
#      27 #scroll down
# ---> 28 scroll_button = driver.find_element(By.XPATH, '//*[@id="mount_0_0_Pp"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[2]')
#      29 scroll_button.click()
#      30 time.sleep(2)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
# ...
