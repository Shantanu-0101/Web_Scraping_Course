# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### Using the input() function

# %%
url = 'https://www.hackthissite.org/user/login'

driver = webdriver.Chrome()
driver.maximize_window()

driver.get(url)
time.sleep(2)

username_field = driver.find_element(By.ID, 'login_username')
password_field = driver.find_element(By.ID, 'login_password')
login_button = driver.find_element(By.XPATH, '/html/body/table/tbody/tr[2]/td/table/tbody/tr/td[2]/form/table/tbody/tr[4]/td/input')

username_field.send_keys('Shantanu')
password_field.send_keys('pass1234')
login_button.click()

captcha_xpath = '/html/body/table/tbody/tr[2]/td/table/tbody/tr/td[2]/form/table/tbody/tr[5]/td/img'
captcha_element = driver.find_element(By.XPATH, captcha_xpath)
if captcha_element:
    x=(input("THis will halt the script, solve captcha for further process:"))

print("Now you are ready to go for further script-")
# Out:
# THis will halt the script, solve captcha for further process: jhg
# Now you are ready to go for further script-
